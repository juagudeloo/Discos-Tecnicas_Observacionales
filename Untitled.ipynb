# %% [markdown]
# # Flux analysis

# %% [markdown]
# ## 1. Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 3. Data Analysis

# %% [markdown]
# ### 3.1 IRAC

# %% [markdown]
# Charge the data resulting from the code run in the [IRAC notebook](./IRAC_notebook.ipynb)

# %%
irac_df = pd.read_csv("Data/IRAC_outputs/Table_IC348.csv")
irac_df
# Out:
#      Unnamed: 0             OBJECT_ID         RA        DEC    1_mag_0  \
# 0             0  2.1662781242585843e+  56.140769  31.975080  13.551206
# 1             1  2.1662911380012454e+  56.213663  31.986909  17.590223
# 2             2  2.16629530412699e+17  56.219711  32.015701  13.797731
# 3             3  2.1662973227464986e+  56.254507  32.040566  15.496543
# 4             4  2.1662987401007654e+  56.267739  32.051545  15.171091
# ..          ...                   ...        ...        ...        ...
# 564         564  2.1671903753111283e+  56.086957  32.345535  13.860935
# 565         565  2.1671931240902336e+  56.022659  32.331783  16.714138
# 566         566  2.1671927375378483e+  56.046041  32.328156  14.152369
# 567         567  2.167193081128224e+1  56.020875  32.334301  20.270370
# 568         568  2.1671924368954765e+  56.023281  32.325271  15.293922
#
#      1_mag_err_0         DATE-OBS_1_mag_0    4_mag_0  4_mag_err_0  \
# ...

# %% [markdown]
# The only meaningful data is the one that has possitive uncertainty value. Let's filter it.

# %%
N_irac_channels = 4
for ch in range(N_irac_channels):
    irac_df = irac_df[irac_df[f"{ch+1}_mag_err_0"] > 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2_mag_err_0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 N_irac_channels = 4
# ...
